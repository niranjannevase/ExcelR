# %% [markdown]
# # SET-1(Descriptive Statistics and Probability)

# %%
import pandas as pd
import scipy 
import numpy as np
import seaborn as sns

from scipy import stats
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
A=pd.Series([24.23,25.53,25.41,24.14,29.62,28.25,25.81,24.39,40.26,32.95,91.36,25.99,39.42,26.71,35.00])

# %%
name=["Allied Signal","Bankers Trust","General Mills","ITT Industries","J.P.Morgan & Co.","Lehman Brothers","Marriott",
"MCI","Merrill Lynch","Microsoft","Morgan Stanley","Sun Microsystems","Travelers","US Airways","Warner-Lambert"]

# %%
sns.boxplot?

# %%
plt.pie(A,labels=name)
plt.show()

# %%
A.describe()
# Out:
# count    15.000000
# mean     33.271333
# std      16.945401
# min      24.140000
# 25%      25.470000
# 50%      26.710000
# 75%      33.975000
# max      91.360000
# dtype: float64

# %%
A.var()
# Out:
# 287.1466123809524

# %%
C=  [(-2000*0.1)+(-1000*0.1)+(0)+(1000*0.2)+( 2000*0.3)+( 3000*0.1)]

# %%
C
# Out:
# [800.0]

# %% [markdown]
# # SET - 02

# %%
# Q no.01
1-stats.norm.cdf(50,45,8)
# Out:
# 0.26598552904870054

# %%
#q no.02
print("the NO of employees at age more than 44:",round(((1-stats.norm.cdf(44,38,6))*400)),0)
print("the NO of employees at  age between 38 and 44:",round((stats.norm.cdf(44,38,6)-stats.norm.cdf(38,38,6))*400),0)
# Out:
# the NO of employees at age more than 44: 63 0
# the NO of employees at  age between 38 and 44: 137 0

# %%
print("No of employees at or below age 30 :",round((stats.norm.cdf(30,38,6))*400,0))
# Out:
# No of employees at or below age 30 : 36.0

# %%
#q no 4
stats.norm.interval(0.99,100,20)
# Out:
# (48.48341392902199, 151.516586070978)

# %%
#q no 5

# %%
# sum of mean from the two profits = 5+7,
mean= 12
print("The mean of the two profit is:",mean*45,"Million Rupees")
# sum of the standard deviation of two profits is S.D= sqrt(9+16) = 5
SD=5
print("the sum of the two profits standard deviation is :",SD*45,"Million Rupees")
# Out:
# The mean of the two profit is: 540 Million Rupees
# the sum of the two profits standard deviation is : 225 Million Rupees

# %%
print("The rupee range that contains 95% of annual probability is:",stats.norm.interval(.95,540,225),"Million rupees")
# Out:
# The rupee range that contains 95% of annual probability is: (99.00810347848784, 980.9918965215122) Million rupees

# %%
# 5th percentile profit
stats.norm.ppf(.05)
# Out:
# -1.6448536269514729

# %%
print("The probability of Profit_1 for loss",stats.norm.cdf(0,5,3))
print("The probability of Profit_2 for loss",stats.norm.cdf(0,7,4))
# Out:
# The probability of Profit_1 for loss 0.0477903522728147
# The probability of Profit_2 for loss 0.040059156863817086

# %% [markdown]
# # set-03

# %%
# Q-no 07
a=stats.norm.interval(0.95)
b=stats.t.interval(0.95,5)

# %%
a
# Out:
# (-1.959963984540054, 1.959963984540054)

# %%
b
# Out:
# (-2.5705818366147395, 2.5705818366147395)

# %%
stats.norm.ppf(0.975)
# Out:
# 1.959963984540054

# %%
stats.norm.ppf(0.99)
# Out:
# 2.3263478740408408

# %% [markdown]
# # set - 04

# %%
# qns no 03
# Z-score for the values range 45 to 55
Z1=(45-50)/40
Z2=(55-50)/40
print ("the Z-score range is :",Z1,"to",Z2 )
# Out:
# the Z-score range is : -0.125 to 0.125

# %%
#probability that 
2*stats.norm.cdf(0.125,50,40)
# Out:
# 0.2124433347629998

# %%
#the probability that in any given week, there will be an investigation is 
## 21.1%

# %%
#qns no 04
print("the Z-score for 5% pprobability is",round(stats.norm.ppf(.025),3))
# Out:
# the Z-score for 5% pprobability is -1.96
